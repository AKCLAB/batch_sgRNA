# %%
import os
# !git clone https://github.com/AKCLAB/batch_sgRNA.git
os.chdir("/content/batch_sgRNA/") # Set this directory
#Another way is to create a shortcut to the batch_sgRNA directory in your own Google Drive and access it this way.
#from google.colab import drive
#drive.mount('/content/drive')
#!ls "/content/drive/MyDrive/batch_sgRNA"
# !pip install CCTop
# !pip install -q condacolab
import condacolab
condacolab.install()
# !conda install -y -c bioconda bowtie
# !conda install -y -c bioconda bedtools
# !pip install pandas

import pandas as pd
import numpy as np
#!which bowtie-build
#!which cctop
# The test directory contains three reference genomes of *Leishmania braziliensis* (MHOM/BR/75/M2903):
# - Beverley version (LBRAZ_M2903.Dec2022.fasta)
# - TriTrypDB version 30 (TriTrypDB-30_LbraziliensisMHOMBR75M2903_Genome.fasta)
# - TriTrypDB version 68 (TriTrypDB-68_LbraziliensisMHOMBR75M2903_Genome.fasta)

# It also includes the file 'ncrna_teste.bed', which contains the start and end coordinates of the target genes.
# df = pd.read_csv("/content/batch_sgRNA/test/ncrna_teste.bed", sep = "\t") # Confer files

# !bash batch_sgrna.sh -bedfile /content/batch_sgRNA/test/ncrna_teste.bed -reffasta /content/batch_sgRNA/test/LBRAZ_M2903.Dec2022.fasta -size_target 50 -size_chr 100
# Out:
# Requirement already satisfied: CCTop in /usr/local/lib/python3.11/site-packages (1.0.1)
# ✨🍰✨ Everything looks OK!
# Channels:
#  - bioconda
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Channels:
#  - bioconda
#  - conda-forge
# Platform: linux-64
# done
# done
#
#
# ==> WARNING: A newer version of conda exists. <==
#     current version: 24.11.3
#     latest version: 25.5.1
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda
#
#
#
# # All requested packages already installed.
#
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# bed file: /content/batch_sgRNA/test/ncrna_teste.bed
# extended size on the chromosome position: 100
# extended size on the target position: 50
# Reference FASTA: /content/batch_sgRNA/test/LBRAZ_M2903.Dec2022.fasta
# output bed: targetprimer
# Extract fasta of initial chomossomal position of ncRNA
# Extract fasta of end position of ncRNA
# Extraction of fasta from new position according to target
# skipping samtools
# Running cctop
# Working on sequence 'LbrM2903_01_v2_pilon_lncRNA21LbrM2903_01_v2_pilon104733-104883'
# Working on sequence 'LbrM2903_01_v2_pilon_lncRNA22LbrM2903_01_v2_pilon108628-108778'
# Working on sequence 'LbrM2903_01_v2_pilon_lncRNA30LbrM2903_01_v2_pilon128449-128599'
# Working on sequence 'LbrM2903_05_v2_pilon_lncRNA1LbrM2903_05_v2_pilon4796-4946'
# Working on sequence 'LbrM2903_05_v2_pilon_lncRNA2LbrM2903_05_v2_pilon5601-5751'
# Working on sequence 'LbrM2903_05_v2_pilon_lncRNA3LbrM2903_05_v2_pilon8372-8522'
# Working on sequence 'LbrM2903_29_v2_pilon_lncRNA114LbrM2903_29_v2_pilon622503-622653'
# Working on sequence 'LbrM2903_12_v2_pilon_lncRNA46LbrM2903_12_v2_pilon234770-234920'
# Working on sequence 'LbrM2903_30_v2_pilon_lncRNA114LbrM2903_30_v2_pilon555628-555778'
# Working on sequence 'LbrM2903_22_v2_pilon_lncRNA116LbrM2903_22_v2_pilon632157-632307'
# Working on sequence 'LbrM2903_35_v2_pilon_lncRNA228LbrM2903_35_v2_pilon1598785-1598935'
# Working on sequence 'LbrM2903_01_v2_pilon_lncRNA21LbrM2903_01_v2_pilon104447-104597'
# Working on sequence 'LbrM2903_01_v2_pilon_lncRNA22LbrM2903_01_v2_pilon107288-107438'
# Working on sequence 'LbrM2903_01_v2_pilon_lncRNA30LbrM2903_01_v2_pilon128195-128345'
# Working on sequence 'LbrM2903_05_v2_pilon_lncRNA1LbrM2903_05_v2_pilon4283-4433'
# Working on sequence 'LbrM2903_05_v2_pilon_lncRNA2LbrM2903_05_v2_pilon4750-4900'
# Working on sequence 'LbrM2903_05_v2_pilon_lncRNA3LbrM2903_05_v2_pilon6973-7123'
# Working on sequence 'LbrM2903_29_v2_pilon_lncRNA114LbrM2903_29_v2_pilon621928-622078'
# Working on sequence 'LbrM2903_12_v2_pilon_lncRNA46LbrM2903_12_v2_pilon234397-234547'
# Working on sequence 'LbrM2903_30_v2_pilon_lncRNA114LbrM2903_30_v2_pilon555264-555414'
# Working on sequence 'LbrM2903_22_v2_pilon_lncRNA116LbrM2903_22_v2_pilon631798-631948'
# Working on sequence 'LbrM2903_35_v2_pilon_lncRNA228LbrM2903_35_v2_pilon1598340-1598490'
# pos-processing output cctop for all genes
# We have the best sgRNAs: cctop_listtop3.tsv
